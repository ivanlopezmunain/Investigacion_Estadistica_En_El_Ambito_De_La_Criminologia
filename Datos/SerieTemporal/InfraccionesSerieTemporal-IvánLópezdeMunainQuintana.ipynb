# %% [markdown]
# ## Red recurrente para predicción del número de infracciones

# %% [markdown]
# ### Iván López de Munain Quintana

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN 
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
import pandas as pd
import keras.backend as K
import matplotlib.pyplot as plt
from sklearn.preprocessing import minmax_scale

# %% [markdown]
# ## Simple RNN

# %%
#Funciones proporcionadas en clase

# Calculates a successfull ratio using less relative error than a maximum criterium
def porcentaje_margen(y_true, y_pred):
    margen = 0.15
    yy = K.sum(K.cast(K.less(K.abs((y_pred/y_true)-1.0), margen), dtype=float))
    return yy/K.cast(K.shape(y_pred)[0], dtype=float)

# Division of a global sequences into n_step size ones (X) with the corresponding prediction desired y
def split_sequence(sequence,n_steps):
    X,y = list(),list()
    for i in range(len(sequence)):
        #find the end of othis pattern
        end_ix = i+n_steps
        #check if we are beyond the sequence 
        if end_ix > len(sequence)-1:  #Cuando no puede mas, se acaba
            break
        #gather input and output parts of the pattern
        seq_x,seq_y = sequence[i:end_ix],sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X),np.array(y)

# %%
tabla_historico=pd.read_excel('datos15-19.xlsx')
print(tabla_historico)

infr=minmax_scale(tabla_historico['Infracciones'])
# Out:
#      Unnamed: 0  Infracciones  Cuatrimestre   Año
# 0             1        131219             1  2015
# 1             2         14641             1  2015
# 2             3          9778             1  2015
# 3             4         17011             1  2015
# 4             5         36013             1  2015
# ..          ...           ...           ...   ...
# 413         414          8946             3  2019
# 414         415         24570             3  2019
# 415         416          2277             3  2019
# 416         417          1354             3  2019
# 417         418          1547             3  2019
#
# [418 rows x 4 columns]

# %%
#Tamaño de las secuencias, en nuestro caso por trimestre cada comunidad
T=19 

# numero de caracteristicas
n_features=1

#conjunto X (19 observaciones por serie)
# observacion y (ultimo valor de cada serie)
x,y=split_sequence(tabla_historico['Infracciones'],T)

#Para normalizar entre [0,15]
#x=x/15
#y=y/15

x=x.reshape(x.shape[0], x.shape[1],1)


#Train y test
#desordeno aleatoriamente los indices y cojo 2/3 para entrenamiento y 1/3 para test
indices=np.arange(y.shape[0],dtype=int)
np.random.shuffle(indices)
train=indices[0:int(y.shape[0]*2/3)]
test=indices[int(y.shape[0]*2/3):]

#train=np.arange(0,304,dtype=int)
#test=np.arange(305,y.shape[0],dtype=int)

#Entrenamiento y validación
SRNN = Sequential()
SRNN.add(SimpleRNN(input_shape=(T,n_features),units=30,activation='relu',return_sequences=True))
SRNN.add(SimpleRNN(10,return_sequences=True,activation="relu"))
SRNN.add(SimpleRNN(5,return_sequences=False,activation="relu"))

#Capa de salida de un perceptrón multicapa
SRNN.add(Dense(1)) 

SRNN.compile(optimizer="adam",loss="mse",metrics=[porcentaje_margen])

history=SRNN.fit(x[train], y[train], epochs=100, verbose=1, validation_data=(x[test],y[test]))
# Out:
# Train on 266 samples, validate on 133 samples
# Epoch 1/100
# 266/266 [==============================] - 11s 43ms/step - loss: 2513202664.9023 - porcentaje_margen: 0.0714 - val_loss: 2836596407.8195 - val_porcentaje_margen: 0.0602
# Epoch 2/100
# 266/266 [==============================] - 2s 7ms/step - loss: 2368824041.8647 - porcentaje_margen: 0.0414 - val_loss: 2614522600.7820 - val_porcentaje_margen: 0.0902
# Epoch 3/100
# 266/266 [==============================] - 2s 9ms/step - loss: 2178675184.6015 - porcentaje_margen: 0.1015 - val_loss: 2307369755.4286 - val_porcentaje_margen: 0.1053
# Epoch 4/100
# 266/266 [==============================] - 2s 9ms/step - loss: 1883405954.8872 - porcentaje_margen: 0.0789 - val_loss: 1821111006.4962 - val_porcentaje_margen: 0.0376
# Epoch 5/100
# 266/266 [==============================] - 2s 9ms/step - loss: 1466368535.0977 - porcentaje_margen: 0.0827 - val_loss: 1320967554.0451 - val_porcentaje_margen: 0.0827
# Epoch 6/100
# 266/266 [==============================] - 2s 8ms/step - loss: 1193805615.1579 - porcentaje_margen: 0.0714 - val_loss: 1103184477.5940 - val_porcentaje_margen: 0.0827
# Epoch 7/100
# 266/266 [==============================] - 2s 8ms/step - loss: 1023256682.8271 - porcentaje_margen: 0.0827 - val_loss: 992121612.7519 - val_porcentaje_margen: 0.1128
# Epoch 8/100
# 266/266 [==============================] - 2s 7ms/step - loss: 917675536.3609 - porcentaje_margen: 0.1165 - val_loss: 811582843.4286 - val_porcentaje_margen: 0.0602
# Epoch 9/100
# 266/266 [==============================] - 2s 6ms/step - loss: 772808987.4286 - porcentaje_margen: 0.0977 - val_loss: 710782406.2556 - val_porcentaje_margen: 0.1128
# Epoch 10/100
# 266/266 [==============================] - 2s 8ms/step - loss: 663119289.2632 - porcentaje_margen: 0.0789 - val_loss: 528850599.6992 - val_porcentaje_margen: 0.0827
# Epoch 11/100
# 266/266 [==============================] - 2s 7ms/step - loss: 541022466.8872 - porcentaje_margen: 0.0865 - val_loss: 381400000.0000 - val_porcentaje_margen: 0.1955
# Epoch 12/100
# 266/266 [==============================] - 2s 7ms/step - loss: 426126233.3835 - porcentaje_margen: 0.2218 - val_loss: 324939245.1128 - val_porcentaje_margen: 0.2331
# Epoch 13/100
# 266/266 [==============================] - 2s 7ms/step - loss: 296461637.3534 - porcentaje_margen: 0.2331 - val_loss: 251543323.2180 - val_porcentaje_margen: 0.2481
# Epoch 14/100
# 266/266 [==============================] - 2s 8ms/step - loss: 227428450.6466 - porcentaje_margen: 0.2632 - val_loss: 145046934.3759 - val_porcentaje_margen: 0.3459
# Epoch 15/100
# 266/266 [==============================] - 2s 9ms/step - loss: 160878519.7895 - porcentaje_margen: 0.3083 - val_loss: 105328596.7068 - val_porcentaje_margen: 0.3008
# Epoch 16/100
# 266/266 [==============================] - 2s 7ms/step - loss: 105438093.4436 - porcentaje_margen: 0.2632 - val_loss: 91572143.5639 - val_porcentaje_margen: 0.3383
# Epoch 17/100
# 266/266 [==============================] - 2s 7ms/step - loss: 86642798.0150 - porcentaje_margen: 0.3346 - val_loss: 71513349.1429 - val_porcentaje_margen: 0.3910
# Epoch 18/100
# 266/266 [==============================] - 2s 8ms/step - loss: 66610312.6015 - porcentaje_margen: 0.3571 - val_loss: 68464366.5714 - val_porcentaje_margen: 0.4436
# Epoch 19/100
# 266/266 [==============================] - 2s 8ms/step - loss: 57057160.9925 - porcentaje_margen: 0.3872 - val_loss: 68425099.1955 - val_porcentaje_margen: 0.4135
# Epoch 20/100
# 266/266 [==============================] - 2s 8ms/step - loss: 65540291.4887 - porcentaje_margen: 0.3647 - val_loss: 65051701.8271 - val_porcentaje_margen: 0.4887
# Epoch 21/100
# 266/266 [==============================] - 2s 9ms/step - loss: 52513635.0226 - porcentaje_margen: 0.4060 - val_loss: 70640130.6767 - val_porcentaje_margen: 0.4211
# Epoch 22/100
# 266/266 [==============================] - 3s 10ms/step - loss: 48261608.3008 - porcentaje_margen: 0.4098 - val_loss: 64582754.9925 - val_porcentaje_margen: 0.4511
# Epoch 23/100
# 266/266 [==============================] - 3s 10ms/step - loss: 47931115.5489 - porcentaje_margen: 0.3985 - val_loss: 58400613.0075 - val_porcentaje_margen: 0.4812
# Epoch 24/100
# 266/266 [==============================] - 2s 9ms/step - loss: 41940933.5639 - porcentaje_margen: 0.4474 - val_loss: 59981393.9549 - val_porcentaje_margen: 0.4887
# Epoch 25/100
# 266/266 [==============================] - 3s 10ms/step - loss: 50737559.3083 - porcentaje_margen: 0.4060 - val_loss: 53512055.5113 - val_porcentaje_margen: 0.5038
# Epoch 26/100
# 266/266 [==============================] - 3s 10ms/step - loss: 40639748.5564 - porcentaje_margen: 0.4323 - val_loss: 52328158.8571 - val_porcentaje_margen: 0.4812
# Epoch 27/100
# 266/266 [==============================] - 2s 9ms/step - loss: 41090138.7669 - porcentaje_margen: 0.4511 - val_loss: 69223483.8045 - val_porcentaje_margen: 0.3985
# Epoch 28/100
# 266/266 [==============================] - 2s 7ms/step - loss: 54461731.5489 - porcentaje_margen: 0.4474 - val_loss: 49509220.7519 - val_porcentaje_margen: 0.5639
# Epoch 29/100
# 266/266 [==============================] - 2s 9ms/step - loss: 50093305.1504 - porcentaje_margen: 0.4511 - val_loss: 48743437.9624 - val_porcentaje_margen: 0.5564
# Epoch 30/100
# 266/266 [==============================] - 2s 9ms/step - loss: 48098849.1429 - porcentaje_margen: 0.4962 - val_loss: 56723897.1316 - val_porcentaje_margen: 0.4962
# Epoch 31/100
# 266/266 [==============================] - 3s 12ms/step - loss: 57337915.6579 - porcentaje_margen: 0.4248 - val_loss: 63894886.8571 - val_porcentaje_margen: 0.4812
# Epoch 32/100
# 266/266 [==============================] - 4s 16ms/step - loss: 43519363.6241 - porcentaje_margen: 0.4361 - val_loss: 46601304.8195 - val_porcentaje_margen: 0.5414
# Epoch 33/100
# 266/266 [==============================] - 2s 8ms/step - loss: 32514884.3308 - porcentaje_margen: 0.5075 - val_loss: 65597817.8797 - val_porcentaje_margen: 0.4511
# Epoch 34/100
# 266/266 [==============================] - 2s 8ms/step - loss: 47497863.6842 - porcentaje_margen: 0.4586 - val_loss: 52050250.6316 - val_porcentaje_margen: 0.5714
# Epoch 35/100
# 266/266 [==============================] - 2s 9ms/step - loss: 38253661.4135 - porcentaje_margen: 0.4474 - val_loss: 50678722.4511 - val_porcentaje_margen: 0.4887
# Epoch 36/100
# 266/266 [==============================] - 3s 11ms/step - loss: 31703822.8571 - porcentaje_margen: 0.4737 - val_loss: 43824374.7293 - val_porcentaje_margen: 0.5714
# Epoch 37/100
# 266/266 [==============================] - 3s 10ms/step - loss: 41808129.3233 - porcentaje_margen: 0.4925 - val_loss: 45259629.4323 - val_porcentaje_margen: 0.5338
# Epoch 38/100
# 266/266 [==============================] - 3s 10ms/step - loss: 37330993.4436 - porcentaje_margen: 0.4662 - val_loss: 54928289.9398 - val_porcentaje_margen: 0.4887
# Epoch 39/100
# 266/266 [==============================] - 2s 9ms/step - loss: 46441702.9323 - porcentaje_margen: 0.4850 - val_loss: 74234302.5038 - val_porcentaje_margen: 0.4211
# Epoch 40/100
# 266/266 [==============================] - 2s 9ms/step - loss: 49490962.4211 - porcentaje_margen: 0.4361 - val_loss: 42458726.3383 - val_porcentaje_margen: 0.5489
# Epoch 41/100
# 266/266 [==============================] - 3s 10ms/step - loss: 42213462.0902 - porcentaje_margen: 0.5075 - val_loss: 51215251.3083 - val_porcentaje_margen: 0.5038
# Epoch 42/100
# 266/266 [==============================] - 3s 10ms/step - loss: 29175673.6692 - porcentaje_margen: 0.5602 - val_loss: 42390195.6767 - val_porcentaje_margen: 0.5789
# Epoch 43/100
# 266/266 [==============================] - 2s 7ms/step - loss: 30681989.1128 - porcentaje_margen: 0.5113 - val_loss: 38144007.5977 - val_porcentaje_margen: 0.5865
# Epoch 44/100
# 266/266 [==============================] - 2s 8ms/step - loss: 27556551.0677 - porcentaje_margen: 0.5602 - val_loss: 38732531.4662 - val_porcentaje_margen: 0.5789
# Epoch 45/100
# 266/266 [==============================] - 2s 8ms/step - loss: 29741523.2782 - porcentaje_margen: 0.5639 - val_loss: 42860812.8797 - val_porcentaje_margen: 0.5639
# Epoch 46/100
# 266/266 [==============================] - 2s 8ms/step - loss: 26932351.6090 - porcentaje_margen: 0.5602 - val_loss: 41880990.5263 - val_porcentaje_margen: 0.5338
# Epoch 47/100
# 266/266 [==============================] - 2s 8ms/step - loss: 26495780.7143 - porcentaje_margen: 0.5188 - val_loss: 39496442.9850 - val_porcentaje_margen: 0.6015
# Epoch 48/100
# 266/266 [==============================] - 2s 8ms/step - loss: 25953302.3684 - porcentaje_margen: 0.5564 - val_loss: 39500083.8872 - val_porcentaje_margen: 0.5639
# Epoch 49/100
# 266/266 [==============================] - 2s 7ms/step - loss: 25049975.8195 - porcentaje_margen: 0.5714 - val_loss: 64090255.6842 - val_porcentaje_margen: 0.3609
# Epoch 50/100
# 266/266 [==============================] - 2s 9ms/step - loss: 67497990.7143 - porcentaje_margen: 0.4474 - val_loss: 57608129.6241 - val_porcentaje_margen: 0.4812
# Epoch 51/100
# 266/266 [==============================] - 3s 11ms/step - loss: 46492043.6692 - porcentaje_margen: 0.4323 - val_loss: 93292142.2857 - val_porcentaje_margen: 0.3835
# Epoch 52/100
# 266/266 [==============================] - 4s 14ms/step - loss: 65454286.9173 - porcentaje_margen: 0.4211 - val_loss: 100336332.0451 - val_porcentaje_margen: 0.4135
# Epoch 53/100
# 266/266 [==============================] - 2s 9ms/step - loss: 51681215.5977 - porcentaje_margen: 0.4737 - val_loss: 42701101.0075 - val_porcentaje_margen: 0.5489
# Epoch 54/100
# 266/266 [==============================] - 3s 10ms/step - loss: 26420960.8120 - porcentaje_margen: 0.5752 - val_loss: 37538528.3835 - val_porcentaje_margen: 0.6015
# Epoch 55/100
# 266/266 [==============================] - 2s 9ms/step - loss: 23972110.4962 - porcentaje_margen: 0.5977 - val_loss: 37473797.0489 - val_porcentaje_margen: 0.5940
# Epoch 56/100
# 266/266 [==============================] - 2s 7ms/step - loss: 26590590.9323 - porcentaje_margen: 0.5714 - val_loss: 35304482.9135 - val_porcentaje_margen: 0.6165
# Epoch 57/100
# 266/266 [==============================] - 2s 7ms/step - loss: 22163942.5038 - porcentaje_margen: 0.5865 - val_loss: 35993255.8233 - val_porcentaje_margen: 0.5940
# Epoch 58/100
# 266/266 [==============================] - 2s 7ms/step - loss: 24037556.8496 - porcentaje_margen: 0.5714 - val_loss: 35001023.9718 - val_porcentaje_margen: 0.5940
# Epoch 59/100
# 266/266 [==============================] - 3s 9ms/step - loss: 23224580.8571 - porcentaje_margen: 0.6353 - val_loss: 50282143.0226 - val_porcentaje_margen: 0.5188
# Epoch 60/100
# 266/266 [==============================] - 2s 8ms/step - loss: 25059838.0150 - porcentaje_margen: 0.6015 - val_loss: 34425605.6241 - val_porcentaje_margen: 0.6391
# Epoch 61/100
# 266/266 [==============================] - 2s 8ms/step - loss: 23208802.5113 - porcentaje_margen: 0.6015 - val_loss: 65622339.3985 - val_porcentaje_margen: 0.4060
# Epoch 62/100
# 266/266 [==============================] - 2s 8ms/step - loss: 43853094.5639 - porcentaje_margen: 0.5038 - val_loss: 70338989.0677 - val_porcentaje_margen: 0.3609
# Epoch 63/100
# 266/266 [==============================] - 2s 6ms/step - loss: 40018791.2030 - porcentaje_margen: 0.5113 - val_loss: 34796865.5977 - val_porcentaje_margen: 0.6165
# Epoch 64/100
# 266/266 [==============================] - 2s 6ms/step - loss: 20683499.6316 - porcentaje_margen: 0.6015 - val_loss: 39442516.3609 - val_porcentaje_margen: 0.5789
# Epoch 65/100
# 266/266 [==============================] - 2s 8ms/step - loss: 24862735.8947 - porcentaje_margen: 0.6165 - val_loss: 36264494.5113 - val_porcentaje_margen: 0.5789
# Epoch 66/100
# 266/266 [==============================] - 2s 8ms/step - loss: 20322473.0301 - porcentaje_margen: 0.5827 - val_loss: 38899524.0526 - val_porcentaje_margen: 0.5789
# Epoch 67/100
# 266/266 [==============================] - 2s 9ms/step - loss: 26302963.6729 - porcentaje_margen: 0.6128 - val_loss: 37283211.9887 - val_porcentaje_margen: 0.6316
# Epoch 68/100
# 266/266 [==============================] - 2s 9ms/step - loss: 25062935.3459 - porcentaje_margen: 0.5940 - val_loss: 55891485.6090 - val_porcentaje_margen: 0.4286
# Epoch 69/100
# 266/266 [==============================] - 2s 9ms/step - loss: 29910403.1541 - porcentaje_margen: 0.5827 - val_loss: 43983863.6466 - val_porcentaje_margen: 0.5188
# Epoch 70/100
# 266/266 [==============================] - 2s 9ms/step - loss: 27411486.1880 - porcentaje_margen: 0.5977 - val_loss: 29973827.9737 - val_porcentaje_margen: 0.6165
# Epoch 71/100
# 266/266 [==============================] - 3s 10ms/step - loss: 23339481.9098 - porcentaje_margen: 0.5451 - val_loss: 32324061.2350 - val_porcentaje_margen: 0.6165
# Epoch 72/100
# 266/266 [==============================] - 3s 10ms/step - loss: 21754442.5714 - porcentaje_margen: 0.5902 - val_loss: 33704517.7180 - val_porcentaje_margen: 0.5639
# Epoch 73/100
# 266/266 [==============================] - 3s 10ms/step - loss: 23286171.2932 - porcentaje_margen: 0.5526 - val_loss: 34066431.5639 - val_porcentaje_margen: 0.5714
# Epoch 74/100
# 266/266 [==============================] - 4s 14ms/step - loss: 22113015.2782 - porcentaje_margen: 0.5902 - val_loss: 38644085.3985 - val_porcentaje_margen: 0.5865
# Epoch 75/100
# 266/266 [==============================] - 2s 9ms/step - loss: 26153460.2782 - porcentaje_margen: 0.6429 - val_loss: 32230690.9173 - val_porcentaje_margen: 0.6090
# Epoch 76/100
# 266/266 [==============================] - 2s 8ms/step - loss: 20160976.6541 - porcentaje_margen: 0.6165 - val_loss: 30947574.2481 - val_porcentaje_margen: 0.6165
# Epoch 77/100
# 266/266 [==============================] - 2s 9ms/step - loss: 19634464.6692 - porcentaje_margen: 0.6429 - val_loss: 31836051.1316 - val_porcentaje_margen: 0.6466
# Epoch 78/100
# 266/266 [==============================] - 2s 8ms/step - loss: 26459329.6241 - porcentaje_margen: 0.5940 - val_loss: 30458176.0827 - val_porcentaje_margen: 0.6466
# Epoch 79/100
# 266/266 [==============================] - 2s 7ms/step - loss: 30833952.9624 - porcentaje_margen: 0.5940 - val_loss: 45719328.4962 - val_porcentaje_margen: 0.5414
# Epoch 80/100
# 266/266 [==============================] - 2s 9ms/step - loss: 24721701.4135 - porcentaje_margen: 0.6203 - val_loss: 55700512.4135 - val_porcentaje_margen: 0.4737
# Epoch 81/100
# 266/266 [==============================] - 3s 11ms/step - loss: 32486384.0075 - porcentaje_margen: 0.4925 - val_loss: 33340338.4060 - val_porcentaje_margen: 0.5489
# Epoch 82/100
# 266/266 [==============================] - 3s 10ms/step - loss: 22982915.9248 - porcentaje_margen: 0.5977 - val_loss: 30506843.1617 - val_porcentaje_margen: 0.6241
# Epoch 83/100
# 266/266 [==============================] - 2s 7ms/step - loss: 21718335.0226 - porcentaje_margen: 0.6504 - val_loss: 28299526.0526 - val_porcentaje_margen: 0.6391
# Epoch 84/100
# 266/266 [==============================] - 2s 8ms/step - loss: 21286566.1429 - porcentaje_margen: 0.6165 - val_loss: 28231362.7218 - val_porcentaje_margen: 0.6617
# Epoch 85/100
# 266/266 [==============================] - 2s 8ms/step - loss: 18533513.8872 - porcentaje_margen: 0.6015 - val_loss: 28362289.2368 - val_porcentaje_margen: 0.6617
# Epoch 86/100
# 266/266 [==============================] - 2s 8ms/step - loss: 21543881.2331 - porcentaje_margen: 0.5602 - val_loss: 33252044.9925 - val_porcentaje_margen: 0.5789
# Epoch 87/100
# 266/266 [==============================] - 4s 15ms/step - loss: 20977535.5038 - porcentaje_margen: 0.6090 - val_loss: 31559380.8440 - val_porcentaje_margen: 0.6090
# Epoch 88/100
# 266/266 [==============================] - 3s 11ms/step - loss: 25455665.0865 - porcentaje_margen: 0.5338 - val_loss: 36527770.1579 - val_porcentaje_margen: 0.5414
# Epoch 89/100
# 266/266 [==============================] - 2s 9ms/step - loss: 27266432.0451 - porcentaje_margen: 0.5489 - val_loss: 35039759.0902 - val_porcentaje_margen: 0.6165
# Epoch 90/100
# 266/266 [==============================] - 2s 9ms/step - loss: 19604954.0752 - porcentaje_margen: 0.6241 - val_loss: 37967012.9662 - val_porcentaje_margen: 0.6241
# Epoch 91/100
# 266/266 [==============================] - 2s 8ms/step - loss: 28059900.1504 - porcentaje_margen: 0.5602 - val_loss: 31756339.3910 - val_porcentaje_margen: 0.6316
# Epoch 92/100
# 266/266 [==============================] - 2s 9ms/step - loss: 22605830.8571 - porcentaje_margen: 0.6241 - val_loss: 60155121.9699 - val_porcentaje_margen: 0.4737
# Epoch 93/100
# 266/266 [==============================] - 3s 11ms/step - loss: 32287450.4060 - porcentaje_margen: 0.4586 - val_loss: 28799616.0752 - val_porcentaje_margen: 0.6391
# Epoch 94/100
# 266/266 [==============================] - 3s 13ms/step - loss: 31250083.0075 - porcentaje_margen: 0.5414 - val_loss: 59229994.4662 - val_porcentaje_margen: 0.4737
# Epoch 95/100
# 266/266 [==============================] - 2s 9ms/step - loss: 42301892.4286 - porcentaje_margen: 0.4850 - val_loss: 30065900.2782 - val_porcentaje_margen: 0.6090
# Epoch 96/100
# 266/266 [==============================] - 2s 9ms/step - loss: 30366629.5338 - porcentaje_margen: 0.5827 - val_loss: 53897927.3985 - val_porcentaje_margen: 0.4511
# Epoch 97/100
# 266/266 [==============================] - 2s 9ms/step - loss: 26425999.9398 - porcentaje_margen: 0.5564 - val_loss: 32447794.9662 - val_porcentaje_margen: 0.6015
# Epoch 98/100
# 266/266 [==============================] - 2s 9ms/step - loss: 23541780.4586 - porcentaje_margen: 0.5752 - val_loss: 27792405.3515 - val_porcentaje_margen: 0.6316
# Epoch 99/100
# 266/266 [==============================] - 2s 9ms/step - loss: 18200357.8195 - porcentaje_margen: 0.6466 - val_loss: 27480946.2368 - val_porcentaje_margen: 0.6466
# Epoch 100/100
# 266/266 [==============================] - 2s 7ms/step - loss: 21399389.3985 - porcentaje_margen: 0.6090 - val_loss: 29108010.1936 - val_porcentaje_margen: 0.6992

# %%
plt.plot(history.epoch,history.history['val_porcentaje_margen'],label='validation')
plt.plot(history.epoch,history.history['porcentaje_margen'],label="training")
plt.legend()
plt.title('Evolución éxito')
plt.xlabel('Epocas')
plt.show()
